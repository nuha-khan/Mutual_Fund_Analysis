# %% [markdown]
# # Data Ingestion and Master Dataset Preparation
#
# This notebook loads the cleaned mutual fund datasets, validates their structure, and combines them into a single master dataset for Power BI dashboard development. It also includes exploratory validation steps performed during the initial phase of the project.

# %% [markdown]
# ## Import Required Libraries
#
# Import the Pandas library for loading, validating, merging, and exporting datasets.

# %%
import pandas as pd

# %% [markdown]
# ## Initial Dataset Exploration
#
# During the initial stage of the project, all raw datasets were inspected to verify their structure, dimensions, data types, and sample records before preprocessing. This exploratory code has been retained as comments for documentation purposes.
